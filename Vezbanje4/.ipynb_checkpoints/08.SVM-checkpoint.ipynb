# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_breast_cancer

# %%
X, y = load_breast_cancer(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123, stratify=y)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = [
    {
        'kernel': ['linear'],
        'C': [0.01, 0.1, 1, 10]
    },
    {
        'kernel': ['rbf'],
        'C': [0.01, 0.1, 1, 10],
        'gamma': [0.01, 0.1, 1, 10]
    }
]

# %%
from sklearn.svm import SVC

# %%
estimator = GridSearchCV(SVC(), param_grid=params, cv=5, verbose=5, scoring='accuracy')

# %%
estimator.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END .............C=0.01, kernel=linear;, score=0.930 total time=   0.0s
# [CV 2/5] END .............C=0.01, kernel=linear;, score=0.976 total time=   0.0s
# [CV 3/5] END .............C=0.01, kernel=linear;, score=0.953 total time=   0.0s
# [CV 4/5] END .............C=0.01, kernel=linear;, score=0.953 total time=   0.0s
# [CV 5/5] END .............C=0.01, kernel=linear;, score=0.988 total time=   0.0s
# [CV 1/5] END ..............C=0.1, kernel=linear;, score=0.942 total time=   0.0s
# [CV 2/5] END ..............C=0.1, kernel=linear;, score=0.988 total time=   0.0s
# [CV 3/5] END ..............C=0.1, kernel=linear;, score=0.976 total time=   0.0s
# [CV 4/5] END ..............C=0.1, kernel=linear;, score=0.976 total time=   0.0s
# [CV 5/5] END ..............C=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END ................C=1, kernel=linear;, score=0.953 total time=   0.0s
# [CV 2/5] END ................C=1, kernel=linear;, score=0.988 total time=   0.0s
# [CV 3/5] END ................C=1, kernel=linear;, score=0.976 total time=   0.0s
# [CV 4/5] END ................C=1, kernel=linear;, score=0.965 total time=   0.0s
# [CV 5/5] END ................C=1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END ...............C=10, kernel=linear;, score=0.977 total time=   0.0s
# [CV 2/5] END ...............C=10, kernel=linear;, score=0.953 total time=   0.0s
# [CV 3/5] END ...............C=10, kernel=linear;, score=0.953 total time=   0.0s
# [CV 4/5] END ...............C=10, kernel=linear;, score=0.965 total time=   0.0s
# [CV 5/5] END ...............C=10, kernel=linear;, score=0.976 total time=   0.0s
# [CV 1/5] END ....C=0.01, gamma=0.01, kernel=rbf;, score=0.628 total time=   0.0s
# [CV 2/5] END ....C=0.01, gamma=0.01, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 3/5] END ....C=0.01, gamma=0.01, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 4/5] END ....C=0.01, gamma=0.01, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 5/5] END ....C=0.01, gamma=0.01, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 1/5] END .....C=0.01, gamma=0.1, kernel=rbf;, score=0.628 total time=   0.0s
# [CV 2/5] END .....C=0.01, gamma=0.1, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 3/5] END .....C=0.01, gamma=0.1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 4/5] END .....C=0.01, gamma=0.1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 5/5] END .....C=0.01, gamma=0.1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 1/5] END .......C=0.01, gamma=1, kernel=rbf;, score=0.628 total time=   0.0s
# [CV 2/5] END .......C=0.01, gamma=1, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 3/5] END .......C=0.01, gamma=1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 4/5] END .......C=0.01, gamma=1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 5/5] END .......C=0.01, gamma=1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 1/5] END ......C=0.01, gamma=10, kernel=rbf;, score=0.628 total time=   0.0s
# [CV 2/5] END ......C=0.01, gamma=10, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 3/5] END ......C=0.01, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 4/5] END ......C=0.01, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 5/5] END ......C=0.01, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.930 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.929 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.941 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.907 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.965 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.906 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.882 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.941 total time=   0.0s
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.628 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 1/5] END .......C=0.1, gamma=10, kernel=rbf;, score=0.628 total time=   0.0s
# [CV 2/5] END .......C=0.1, gamma=10, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 3/5] END .......C=0.1, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 4/5] END .......C=0.1, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 5/5] END .......C=0.1, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.930 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.930 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.628 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.647 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 1/5] END .........C=1, gamma=10, kernel=rbf;, score=0.628 total time=   0.0s
# [CV 2/5] END .........C=1, gamma=10, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 3/5] END .........C=1, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 4/5] END .........C=1, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 5/5] END .........C=1, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.942 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.965 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.942 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.965 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.628 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.647 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 1/5] END ........C=10, gamma=10, kernel=rbf;, score=0.628 total time=   0.0s
# [CV 2/5] END ........C=10, gamma=10, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 3/5] END ........C=10, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 4/5] END ........C=10, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 5/5] END ........C=10, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid=[{'C': [0.01, 0.1, 1, 10], 'kernel': ['linear']},
#                          {'C': [0.01, 0.1, 1, 10], 'gamma': [0.01, 0.1, 1, 10],
#                           'kernel': ['rbf']}],
#              scoring='accuracy', verbose=5)

# %%
estimator.best_estimator_
# Out:
# SVC(C=10, gamma=0.01)

# %%
model = estimator.best_estimator_

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score

# %%
y_train_pred = model.predict(X_train)

# %%
confusion_matrix(y_train, y_train_pred)
# Out:
# array([[153,   6],
#        [  0, 267]])

# %%
accuracy_score(y_train, y_train_pred)
# Out:
# 0.9859154929577465

# %%
f1_score(y_train, y_train_pred)
# Out:
# 0.9888888888888889

# %%
y_test_pred = model.predict(X_test)

# %%
confusion_matrix(y_test, y_test_pred)
# Out:
# array([[50,  3],
#        [ 0, 90]])

# %%
accuracy_score(y_test, y_test_pred)
# Out:
# 0.9790209790209791

# %%
f1_score(y_test, y_test_pred)
# Out:
# 0.9836065573770492

# %%
# Kerneli

# %%
num_instances = 1000
X = np.random.uniform(low=-1, high=1, size=(num_instances, 2))

# %%
def f(x, y):
    return x**2 + y**2 <= 0.5

# %%
y = f(X[:,0], X[:,1])

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
model = SVC(kernel='linear')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123, stratify=y)

# %%
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_train_pred = model.predict(X_train)

# %%
accuracy_score(y_train, y_train_pred)
# Out:
# 0.5786666666666667

# %%
y_test_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_test_pred)
# Out:
# 0.58

# %%
model = SVC(kernel='rbf')

# %%
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_train_pred = model.predict(X_train)

# %%
accuracy_score(y_train, y_train_pred)
# Out:
# 0.9826666666666667

# %%
y_test_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_test_pred)
# Out:
# 0.976

# %%
print(f'Broj potpornih vektora: {model.n_support_}')
# Out:
# Broj potpornih vektora: [87 84]

# %%
print(f'Indeksi instanci koji su potporni vektori: {model.support_}')
# Out:
# Indeksi instanci koji su potporni vektori: [  9  16  29  32  36  52  57  58  61  79  83  98  99 100 111 119 129 136
#  137 144 156 157 163 195 205 214 225 230 232 236 246 247 274 278 280 282
#  288 292 296 310 317 323 334 339 347 358 390 400 401 404 415 418 452 455
#  466 472 484 496 508 510 512 528 545 549 560 561 580 587 607 613 621 639
