# %%
# !pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.12.3-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 394.5 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting joblib>=1.1.1
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 561.9 kB/s eta 0:00:00 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /home/natasa/anaconda3/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (1.21.5)
# Requirement already satisfied: scipy>=1.5.0 in /home/natasa/anaconda3/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (1.9.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /home/natasa/anaconda3/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/natasa/anaconda3/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Installing collected packages: joblib, imbalanced-learn, imblearn
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
# Successfully installed imbalanced-learn-0.12.3 imblearn-0.0 joblib-1.4.2

# %%
import pandas as pd
import numpy as np
from imblearn.datasets import fetch_datasets

# %%
mammography = fetch_datasets()['mammography']
mammography
# Out:
# {'data': array([[ 0.23001961,  5.0725783 , -0.27606055,  0.83244412, -0.37786573,
#           0.4803223 ],
#         [ 0.15549112, -0.16939038,  0.67065219, -0.85955255, -0.37786573,
#          -0.94572324],
#         [-0.78441482, -0.44365372,  5.6747053 , -0.85955255, -0.37786573,
#          -0.94572324],
#         ...,
#         [ 1.2049878 ,  1.7637238 , -0.50146835,  1.5624078 ,  6.4890725 ,
#           0.93129397],
#         [ 0.73664398, -0.22247361, -0.05065276,  1.5096647 ,  0.53926914,
#           1.3152293 ],
#         [ 0.17700275, -0.19150839, -0.50146835,  1.5788636 ,  7.750705  ,
#           1.5559507 ]]),
#  'target': array([-1, -1, -1, ...,  1,  1,  1]),
#  'DESCR': 'mammography'}

# %%
X = pd.DataFrame(mammography.data)

# %%
y = pd.DataFrame(mammography.target)

# %%
X.shape
# Out:
# (11183, 6)

# %%
X.describe()
# Out:
#                   0             1             2             3             4  \
# count  1.118300e+04  1.118300e+04  1.118300e+04  1.118300e+04  1.118300e+04
# mean   1.096535e-10  1.297595e-09  5.698113e-10 -2.435705e-09 -1.120680e-09
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -7.844148e-01 -4.701953e-01 -5.916315e-01 -8.595525e-01 -3.778657e-01
# 25%   -7.844148e-01 -4.701953e-01 -5.916315e-01 -8.595525e-01 -3.778657e-01
# 50%   -1.085769e-01 -3.949941e-01 -2.309790e-01 -8.595525e-01 -3.778657e-01
# 75%    3.139489e-01 -7.649473e-02  2.198366e-01  8.202077e-01 -3.778657e-01
# max    3.150844e+01  5.085849e+00  2.947777e+01  9.591164e+00  2.361712e+01
#
#                   5
# count  1.118300e+04
# mean   1.459483e-09
# std    1.000000e+00
# min   -9.457232e-01
# 25%   -9.457232e-01
# 50%   -9.457232e-01
# 75%    1.016613e+00
# max    1.949027e+00

# %%
import matplotlib.pyplot as plt

# %%
lines, edge, bins = plt.hist(y, bins=2)
plt.bar_label(bins)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123, stratify=y)

# %%
from imblearn.metrics import classification_report_imbalanced
from sklearn.metrics import confusion_matrix

# %%
def report(y, y_pred):
    print(classification_report_imbalanced(y, y_pred))
    print('-'*100)
    print(pd.DataFrame(confusion_matrix(y, y_pred), columns=['B', 'M'], index=['B', 'M']))

# %%
def resample(sampler, X, Y):
    X_resampled, y_resampled = sampler.fit_resample(X, Y)
    
    return X_resampled, y_resampled

# %%
from sklearn.decomposition import PCA

# %%
def visualize(X, X_resampled, Y, Y_resamnpled, x_opacity=0.5):
    pca = PCA(n_components=2)
    pca.fit(X)
    
    X_pca = pca.transform(X)
    X_resampled_pca = pca.transform(X_resampled)
    
    X_stacked = [X_pca, X_resampled_pca]
    Y_stacked = [Y, Y_resamnpled]
    
    fig = plt.figure(figsize=(20,5))
    
    for i in range(2):
        ax = plt.subplot(1, 2, i+1)
        colors = ['b' if y == -1 else 'r' for y in Y_stacked[i]]
        alpha = [x_opacity if y == -1 else 1 - x_opacity for y in Y_stacked[i]]
        plt.scatter(X_stacked[i][:,0], X_stacked[i][:,1], c=colors, alpha=alpha)
        plt.title(f'{"After" if i else "Before"}', c='blue' if i else 'green')\
        
    plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
def train_and_evaluate(X_train, Y_train, X_test, Y_test):
    model = DecisionTreeClassifier(max_depth=7, min_samples_split=25, criterion='gini')
    model.fit(X_train, Y_train)
    print('Trening skup:')
    report(Y_train, model.predict(X_train))
    print('='*100)
    print('Test skup')
    report(Y_test, model.predict(X_test))
    
    return model

# %%
# Over-sampling

## RandomOverSampler

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=0, sampling_strategy='minority')

# %%
X_res, y_res = resample(ros, X_train, y_train)

# %%
visualize(X_train, X_res, y_train, y_res)

# %%
model_ros = train_and_evaluate(X_res, y_res, X_test, y_test)
# Out:
# Trening skup:
#                    pre       rec       spe        f1       geo       iba       sup
#
#          -1       0.95      0.96      0.95      0.95      0.95      0.91      8192
#           1       0.96      0.95      0.96      0.95      0.95      0.91      8192
#
# avg / total       0.95      0.95      0.95      0.95      0.95      0.91     16384
#
# ----------------------------------------------------------------------------------------------------
#       B     M
# B  7865   327
# M   444  7748
# ====================================================================================================
# Test skup
#                    pre       rec       spe        f1       geo       iba       sup
#
#          -1       0.99      0.95      0.75      0.97      0.85      0.73      2731
#           1       0.28      0.75      0.95      0.41      0.85      0.70        65
#
# avg / total       0.98      0.95      0.76      0.96      0.85      0.73      2796
#
# ----------------------------------------------------------------------------------------------------
#       B    M
# B  2606  125
# M    16   49

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(k_neighbors=10, random_state=42)

# %%
X_res, y_res = resample(smote, X_train, y_train)

# %%
visualize(X_train, X_res, y_train, y_res)

# %%
model_smote = train_and_evaluate(X_res, y_res, X_test, y_test)
# Out:
# Trening skup:
#                    pre       rec       spe        f1       geo       iba       sup
#
#          -1       0.95      0.96      0.95      0.95      0.95      0.91      8192
#           1       0.96      0.95      0.96      0.95      0.95      0.91      8192
#
# avg / total       0.95      0.95      0.95      0.95      0.95      0.91     16384
#
# ----------------------------------------------------------------------------------------------------
#       B     M
# B  7865   327
# M   444  7748
# ====================================================================================================
# Test skup
#                    pre       rec       spe        f1       geo       iba       sup
#
#          -1       0.99      0.95      0.74      0.97      0.84      0.72      2731
#           1       0.28      0.74      0.95      0.41      0.84      0.69        65
#
# avg / total       0.98      0.95      0.74      0.96      0.84      0.72      2796
#
# ----------------------------------------------------------------------------------------------------
#       B    M
# B  2607  124
# M    17   48

# %%
# Under-sampling

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus = RandomUnderSampler()

# %%
X_res, y_res = resample(rus, X_train, y_train)

# %%
visualize(X_train, X_res, y_train, y_res)

# %%
model_rus = train_and_evaluate(X_res, y_res, X_test, y_test)
# Out:
# Trening skup:
#                    pre       rec       spe        f1       geo       iba       sup
#
#          -1       0.89      0.92      0.89      0.91      0.90      0.82       195
#           1       0.92      0.89      0.92      0.90      0.90      0.82       195
#
# avg / total       0.91      0.91      0.91      0.91      0.90      0.82       390
#
# ----------------------------------------------------------------------------------------------------
#      B    M
# B  180   15
# M   22  173
# ====================================================================================================
# Test skup
#                    pre       rec       spe        f1       geo       iba       sup
#
#          -1       1.00      0.91      0.82      0.95      0.86      0.75      2731
#           1       0.17      0.82      0.91      0.29      0.86      0.73        65
#
# avg / total       0.98      0.91      0.82      0.93      0.86      0.75      2796
#
# ----------------------------------------------------------------------------------------------------
#       B    M
# B  2481  250
# M    12   53
