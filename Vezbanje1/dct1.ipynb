# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../datasets/data.csv')

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
data.isna().any()
# Out:
# id                         False
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                False
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst            False
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# concavity_worst            False
# concave points_worst       False
# symmetry_worst             False
# fractal_dimension_worst    False
# Unnamed: 32                 True
# dtype: bool

# %%
data.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
data.drop('Unnamed: 32', axis=1, inplace=True)

# %%
data.drop('id', axis=1, inplace=True)

# %%
data.isna().any().any()
# Out:
# False

# %%
data.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
Y = data['diagnosis']
X = data.drop('diagnosis', axis=1)

# %%
Y.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
Y.replace('B', 0, inplace=True)

# %%
Y.replace('M', 1, inplace=True)

# %%
Y.unique()
# Out:
# array([1, 0])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
def report(y, y_pred):
    print(classification_report(y, y_pred))
    print('-'*100)
    print(pd.DataFrame(confusion_matrix(y, y_pred), columns=['B', 'M'], index=['B', 'M']))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=123, stratify=Y)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
report(y_train, model.predict(X_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       267
#            1       1.00      1.00      1.00       159
#
#     accuracy                           1.00       426
#    macro avg       1.00      1.00      1.00       426
# weighted avg       1.00      1.00      1.00       426
#
# ----------------------------------------------------------------------------------------------------
#      B    M
# B  267    0
# M    0  159

# %%
report(y_test, model.predict(X_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96        90
#            1       0.91      0.94      0.93        53
#
#     accuracy                           0.94       143
#    macro avg       0.94      0.94      0.94       143
# weighted avg       0.94      0.94      0.94       143
#
# ----------------------------------------------------------------------------------------------------
#     B   M
# B  85   5
# M   3  50

# %%
from sklearn.model_selection import GridSearchCV

# %%
model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
params = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [2,4,6,8,10]
}

# %%
estimator = GridSearchCV(DecisionTreeClassifier(), param_grid=params, cv=5, verbose=5)

# %%
estimator.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END .......criterion=gini, max_depth=2;, score=0.942 total time=   0.0s
# [CV 2/5] END .......criterion=gini, max_depth=2;, score=0.941 total time=   0.0s
# [CV 3/5] END .......criterion=gini, max_depth=2;, score=0.906 total time=   0.0s
# [CV 4/5] END .......criterion=gini, max_depth=2;, score=0.871 total time=   0.0s
# [CV 5/5] END .......criterion=gini, max_depth=2;, score=0.929 total time=   0.0s
# [CV 1/5] END .......criterion=gini, max_depth=4;, score=0.942 total time=   0.0s
# [CV 2/5] END .......criterion=gini, max_depth=4;, score=0.941 total time=   0.0s
# [CV 3/5] END .......criterion=gini, max_depth=4;, score=0.929 total time=   0.0s
# [CV 4/5] END .......criterion=gini, max_depth=4;, score=0.894 total time=   0.0s
# [CV 5/5] END .......criterion=gini, max_depth=4;, score=0.941 total time=   0.0s
# [CV 1/5] END .......criterion=gini, max_depth=6;, score=0.930 total time=   0.0s
# [CV 2/5] END .......criterion=gini, max_depth=6;, score=0.976 total time=   0.0s
# [CV 3/5] END .......criterion=gini, max_depth=6;, score=0.906 total time=   0.0s
# [CV 4/5] END .......criterion=gini, max_depth=6;, score=0.859 total time=   0.0s
# [CV 5/5] END .......criterion=gini, max_depth=6;, score=0.929 total time=   0.0s
# [CV 1/5] END .......criterion=gini, max_depth=8;, score=0.919 total time=   0.0s
# [CV 2/5] END .......criterion=gini, max_depth=8;, score=0.941 total time=   0.0s
# [CV 3/5] END .......criterion=gini, max_depth=8;, score=0.929 total time=   0.0s
# [CV 4/5] END .......criterion=gini, max_depth=8;, score=0.859 total time=   0.0s
# [CV 5/5] END .......criterion=gini, max_depth=8;, score=0.929 total time=   0.0s
# [CV 1/5] END ......criterion=gini, max_depth=10;, score=0.930 total time=   0.0s
# [CV 2/5] END ......criterion=gini, max_depth=10;, score=0.941 total time=   0.0s
# [CV 3/5] END ......criterion=gini, max_depth=10;, score=0.906 total time=   0.0s
# [CV 4/5] END ......criterion=gini, max_depth=10;, score=0.859 total time=   0.0s
# [CV 5/5] END ......criterion=gini, max_depth=10;, score=0.941 total time=   0.0s
# [CV 1/5] END ....criterion=entropy, max_depth=2;, score=0.942 total time=   0.0s
# [CV 2/5] END ....criterion=entropy, max_depth=2;, score=0.976 total time=   0.0s
# [CV 3/5] END ....criterion=entropy, max_depth=2;, score=0.906 total time=   0.0s
# [CV 4/5] END ....criterion=entropy, max_depth=2;, score=0.859 total time=   0.0s
# [CV 5/5] END ....criterion=entropy, max_depth=2;, score=0.882 total time=   0.0s
# [CV 1/5] END ....criterion=entropy, max_depth=4;, score=0.953 total time=   0.0s
# [CV 2/5] END ....criterion=entropy, max_depth=4;, score=0.976 total time=   0.0s
# [CV 3/5] END ....criterion=entropy, max_depth=4;, score=0.906 total time=   0.0s
# [CV 4/5] END ....criterion=entropy, max_depth=4;, score=0.894 total time=   0.0s
# [CV 5/5] END ....criterion=entropy, max_depth=4;, score=0.941 total time=   0.0s
# [CV 1/5] END ....criterion=entropy, max_depth=6;, score=0.942 total time=   0.0s
# [CV 2/5] END ....criterion=entropy, max_depth=6;, score=0.965 total time=   0.0s
# [CV 3/5] END ....criterion=entropy, max_depth=6;, score=0.929 total time=   0.0s
# [CV 4/5] END ....criterion=entropy, max_depth=6;, score=0.882 total time=   0.0s
# [CV 5/5] END ....criterion=entropy, max_depth=6;, score=0.941 total time=   0.0s
# [CV 1/5] END ....criterion=entropy, max_depth=8;, score=0.942 total time=   0.0s
# [CV 2/5] END ....criterion=entropy, max_depth=8;, score=0.965 total time=   0.0s
# [CV 3/5] END ....criterion=entropy, max_depth=8;, score=0.918 total time=   0.0s
# [CV 4/5] END ....criterion=entropy, max_depth=8;, score=0.882 total time=   0.0s
# [CV 5/5] END ....criterion=entropy, max_depth=8;, score=0.941 total time=   0.0s
# [CV 1/5] END ...criterion=entropy, max_depth=10;, score=0.942 total time=   0.0s
# [CV 2/5] END ...criterion=entropy, max_depth=10;, score=0.988 total time=   0.0s
# [CV 3/5] END ...criterion=entropy, max_depth=10;, score=0.918 total time=   0.0s
# [CV 4/5] END ...criterion=entropy, max_depth=10;, score=0.859 total time=   0.0s
# [CV 5/5] END ...criterion=entropy, max_depth=10;, score=0.941 total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10]},
#              verbose=5)

# %%
estimator.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
model = estimator.best_estimator_

# %%
report(y_test, model.predict(X_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95        90
#            1       0.89      0.94      0.92        53
#
#     accuracy                           0.94       143
#    macro avg       0.93      0.94      0.93       143
# weighted avg       0.94      0.94      0.94       143
#
# ----------------------------------------------------------------------------------------------------
#     B   M
# B  84   6
# M   3  50

# %%
report(y_train, model.predict(X_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       267
#            1       0.99      0.96      0.98       159
#
#     accuracy                           0.98       426
#    macro avg       0.99      0.98      0.98       426
# weighted avg       0.98      0.98      0.98       426
#
# ----------------------------------------------------------------------------------------------------
#      B    M
# B  266    1
# M    6  153

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(12,8))
plot_tree(model, feature_names=X.columns, filled=True)
plt.title(f'DecisionTreeClassifier with {model.get_depth()} depth')
plt.show()
