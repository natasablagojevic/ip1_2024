# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../datasets/data.csv')

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
data.isna().any()
# Out:
# id                         False
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                False
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst            False
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# concavity_worst            False
# concave points_worst       False
# symmetry_worst             False
# fractal_dimension_worst    False
# Unnamed: 32                 True
# dtype: bool

# %%
data.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
data.shape
# Out:
# (569, 33)

# %%
data.drop('Unnamed: 32', axis=1, inplace=True)

# %%
data.drop('id', axis=1, inplace=True)

# %%
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.2419  ...        25.380          17.33           184.60
# 1           0.1812  ...        24.990          23.41           158.80
# 2           0.2069  ...        23.570          25.53           152.50
# 3           0.2597  ...        14.910          26.50            98.87
# 4           0.1809  ...        22.540          16.67           152.20
# ..             ...  ...           ...            ...              ...
# 564         0.1726  ...        25.450          26.40           166.10
# 565         0.1752  ...        23.690          38.25           155.00
# 566         0.1590  ...        18.980          34.12           126.70
# 567         0.2397  ...        25.740          39.42           184.60
# 568         0.1587  ...         9.456          30.37            59.16
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
data.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
Y = data['diagnosis']
X = data.drop('diagnosis', axis=1)

# %%
feature_names = X.columns

# %%
Y.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
plt.figure(figsize=(8,8))

Y.hist()
# Out:
# <AxesSubplot:>

# %%
Y.replace('B', 0, inplace=True)

# %%
Y.replace('M', 1, inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
def report(y, y_pred):
    print(classification_report(y, y_pred))
    print('-'*100)
    print(pd.DataFrame(confusion_matrix(y, y_pred), index=['B', 'M'], columns=['B', 'M']))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=123, stratify=Y)

# %%
X_train.shape
# Out:
# (426, 30)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
report(y_train, model.predict(X_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       267
#            1       0.98      0.96      0.97       159
#
#     accuracy                           0.98       426
#    macro avg       0.98      0.97      0.97       426
# weighted avg       0.98      0.98      0.98       426
#
# ----------------------------------------------------------------------------------------------------
#      B    M
# B  264    3
# M    7  152

# %%
report(y_test, model.predict(X_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        90
#            1       0.94      0.94      0.94        53
#
#     accuracy                           0.96       143
#    macro avg       0.96      0.96      0.96       143
# weighted avg       0.96      0.96      0.96       143
#
# ----------------------------------------------------------------------------------------------------
#     B   M
# B  87   3
# M   3  50

# %%
from sklearn.model_selection import GridSearchCV

# %%
model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
params = {
    'n_neighbors': range(10, 50, 5),
    'weights': ['uniform', 'distance'],
    'p': [1, 2]
}

# %%
estimator = GridSearchCV(KNeighborsClassifier(), param_grid=params, cv=5, verbose=5)

# %%
estimator.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5] END n_neighbors=10, p=1, weights=uniform;, score=0.988 total time=   0.0s
# [CV 2/5] END n_neighbors=10, p=1, weights=uniform;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=10, p=1, weights=uniform;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=10, p=1, weights=uniform;, score=0.918 total time=   0.0s
# [CV 5/5] END n_neighbors=10, p=1, weights=uniform;, score=0.976 total time=   0.0s
# [CV 1/5] END n_neighbors=10, p=1, weights=distance;, score=0.988 total time=   0.0s
# [CV 2/5] END n_neighbors=10, p=1, weights=distance;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=10, p=1, weights=distance;, score=0.965 total time=   0.0s
# [CV 4/5] END n_neighbors=10, p=1, weights=distance;, score=0.953 total time=   0.0s
# [CV 5/5] END n_neighbors=10, p=1, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=10, p=2, weights=uniform;, score=0.977 total time=   0.0s
# [CV 2/5] END n_neighbors=10, p=2, weights=uniform;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=10, p=2, weights=uniform;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=10, p=2, weights=uniform;, score=0.918 total time=   0.0s
# [CV 5/5] END n_neighbors=10, p=2, weights=uniform;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=10, p=2, weights=distance;, score=0.977 total time=   0.0s
# [CV 2/5] END n_neighbors=10, p=2, weights=distance;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=10, p=2, weights=distance;, score=0.965 total time=   0.0s
# [CV 4/5] END n_neighbors=10, p=2, weights=distance;, score=0.918 total time=   0.0s
# [CV 5/5] END n_neighbors=10, p=2, weights=distance;, score=0.976 total time=   0.0s
# [CV 1/5] END n_neighbors=15, p=1, weights=uniform;, score=0.965 total time=   0.0s
# [CV 2/5] END n_neighbors=15, p=1, weights=uniform;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=15, p=1, weights=uniform;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=15, p=1, weights=uniform;, score=0.918 total time=   0.0s
# [CV 5/5] END n_neighbors=15, p=1, weights=uniform;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=15, p=1, weights=distance;, score=0.977 total time=   0.0s
# [CV 2/5] END n_neighbors=15, p=1, weights=distance;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=15, p=1, weights=distance;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=15, p=1, weights=distance;, score=0.929 total time=   0.0s
# [CV 5/5] END n_neighbors=15, p=1, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=15, p=2, weights=uniform;, score=0.977 total time=   0.0s
# [CV 2/5] END n_neighbors=15, p=2, weights=uniform;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=15, p=2, weights=uniform;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=15, p=2, weights=uniform;, score=0.929 total time=   0.0s
# [CV 5/5] END n_neighbors=15, p=2, weights=uniform;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=15, p=2, weights=distance;, score=0.977 total time=   0.0s
# [CV 2/5] END n_neighbors=15, p=2, weights=distance;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=15, p=2, weights=distance;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=15, p=2, weights=distance;, score=0.929 total time=   0.0s
# [CV 5/5] END n_neighbors=15, p=2, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=20, p=1, weights=uniform;, score=0.942 total time=   0.0s
# [CV 2/5] END n_neighbors=20, p=1, weights=uniform;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=20, p=1, weights=uniform;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=20, p=1, weights=uniform;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=20, p=1, weights=uniform;, score=0.976 total time=   0.0s
# [CV 1/5] END n_neighbors=20, p=1, weights=distance;, score=0.965 total time=   0.0s
# [CV 2/5] END n_neighbors=20, p=1, weights=distance;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=20, p=1, weights=distance;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=20, p=1, weights=distance;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=20, p=1, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=20, p=2, weights=uniform;, score=0.965 total time=   0.0s
# [CV 2/5] END n_neighbors=20, p=2, weights=uniform;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=20, p=2, weights=uniform;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=20, p=2, weights=uniform;, score=0.918 total time=   0.0s
# [CV 5/5] END n_neighbors=20, p=2, weights=uniform;, score=0.976 total time=   0.0s
# [CV 1/5] END n_neighbors=20, p=2, weights=distance;, score=0.977 total time=   0.0s
# [CV 2/5] END n_neighbors=20, p=2, weights=distance;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=20, p=2, weights=distance;, score=0.965 total time=   0.0s
# [CV 4/5] END n_neighbors=20, p=2, weights=distance;, score=0.918 total time=   0.0s
# [CV 5/5] END n_neighbors=20, p=2, weights=distance;, score=0.976 total time=   0.0s
# [CV 1/5] END n_neighbors=25, p=1, weights=uniform;, score=0.942 total time=   0.0s
# [CV 2/5] END n_neighbors=25, p=1, weights=uniform;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=25, p=1, weights=uniform;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=25, p=1, weights=uniform;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=25, p=1, weights=uniform;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=25, p=1, weights=distance;, score=0.953 total time=   0.0s
# [CV 2/5] END n_neighbors=25, p=1, weights=distance;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=25, p=1, weights=distance;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=25, p=1, weights=distance;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=25, p=1, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=25, p=2, weights=uniform;, score=0.977 total time=   0.0s
# [CV 2/5] END n_neighbors=25, p=2, weights=uniform;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=25, p=2, weights=uniform;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=25, p=2, weights=uniform;, score=0.918 total time=   0.0s
# [CV 5/5] END n_neighbors=25, p=2, weights=uniform;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=25, p=2, weights=distance;, score=0.977 total time=   0.0s
# [CV 2/5] END n_neighbors=25, p=2, weights=distance;, score=1.000 total time=   0.0s
# [CV 3/5] END n_neighbors=25, p=2, weights=distance;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=25, p=2, weights=distance;, score=0.918 total time=   0.0s
# [CV 5/5] END n_neighbors=25, p=2, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=30, p=1, weights=uniform;, score=0.942 total time=   0.0s
# [CV 2/5] END n_neighbors=30, p=1, weights=uniform;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=30, p=1, weights=uniform;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=30, p=1, weights=uniform;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=30, p=1, weights=uniform;, score=0.976 total time=   0.0s
# [CV 1/5] END n_neighbors=30, p=1, weights=distance;, score=0.942 total time=   0.0s
# [CV 2/5] END n_neighbors=30, p=1, weights=distance;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=30, p=1, weights=distance;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=30, p=1, weights=distance;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=30, p=1, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=30, p=2, weights=uniform;, score=0.942 total time=   0.0s
# [CV 2/5] END n_neighbors=30, p=2, weights=uniform;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=30, p=2, weights=uniform;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=30, p=2, weights=uniform;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=30, p=2, weights=uniform;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=30, p=2, weights=distance;, score=0.942 total time=   0.0s
# [CV 2/5] END n_neighbors=30, p=2, weights=distance;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=30, p=2, weights=distance;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=30, p=2, weights=distance;, score=0.918 total time=   0.0s
# [CV 5/5] END n_neighbors=30, p=2, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=35, p=1, weights=uniform;, score=0.942 total time=   0.0s
# [CV 2/5] END n_neighbors=35, p=1, weights=uniform;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=35, p=1, weights=uniform;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=35, p=1, weights=uniform;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=35, p=1, weights=uniform;, score=0.976 total time=   0.0s
# [CV 1/5] END n_neighbors=35, p=1, weights=distance;, score=0.953 total time=   0.0s
# [CV 2/5] END n_neighbors=35, p=1, weights=distance;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=35, p=1, weights=distance;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=35, p=1, weights=distance;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=35, p=1, weights=distance;, score=0.976 total time=   0.0s
# [CV 1/5] END n_neighbors=35, p=2, weights=uniform;, score=0.942 total time=   0.0s
# [CV 2/5] END n_neighbors=35, p=2, weights=uniform;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=35, p=2, weights=uniform;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=35, p=2, weights=uniform;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=35, p=2, weights=uniform;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=35, p=2, weights=distance;, score=0.942 total time=   0.0s
# [CV 2/5] END n_neighbors=35, p=2, weights=distance;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=35, p=2, weights=distance;, score=0.953 total time=   0.0s
# [CV 4/5] END n_neighbors=35, p=2, weights=distance;, score=0.918 total time=   0.0s
# [CV 5/5] END n_neighbors=35, p=2, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=40, p=1, weights=uniform;, score=0.930 total time=   0.0s
# [CV 2/5] END n_neighbors=40, p=1, weights=uniform;, score=0.976 total time=   0.0s
# [CV 3/5] END n_neighbors=40, p=1, weights=uniform;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=40, p=1, weights=uniform;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=40, p=1, weights=uniform;, score=0.976 total time=   0.0s
# [CV 1/5] END n_neighbors=40, p=1, weights=distance;, score=0.953 total time=   0.0s
# [CV 2/5] END n_neighbors=40, p=1, weights=distance;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=40, p=1, weights=distance;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=40, p=1, weights=distance;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=40, p=1, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=40, p=2, weights=uniform;, score=0.953 total time=   0.0s
# [CV 2/5] END n_neighbors=40, p=2, weights=uniform;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=40, p=2, weights=uniform;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=40, p=2, weights=uniform;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=40, p=2, weights=uniform;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=40, p=2, weights=distance;, score=0.953 total time=   0.0s
# [CV 2/5] END n_neighbors=40, p=2, weights=distance;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=40, p=2, weights=distance;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=40, p=2, weights=distance;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=40, p=2, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=45, p=1, weights=uniform;, score=0.930 total time=   0.0s
# [CV 2/5] END n_neighbors=45, p=1, weights=uniform;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=45, p=1, weights=uniform;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=45, p=1, weights=uniform;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=45, p=1, weights=uniform;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=45, p=1, weights=distance;, score=0.953 total time=   0.0s
# [CV 2/5] END n_neighbors=45, p=1, weights=distance;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=45, p=1, weights=distance;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=45, p=1, weights=distance;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=45, p=1, weights=distance;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=45, p=2, weights=uniform;, score=0.953 total time=   0.0s
# [CV 2/5] END n_neighbors=45, p=2, weights=uniform;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=45, p=2, weights=uniform;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=45, p=2, weights=uniform;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=45, p=2, weights=uniform;, score=0.965 total time=   0.0s
# [CV 1/5] END n_neighbors=45, p=2, weights=distance;, score=0.953 total time=   0.0s
# [CV 2/5] END n_neighbors=45, p=2, weights=distance;, score=0.988 total time=   0.0s
# [CV 3/5] END n_neighbors=45, p=2, weights=distance;, score=0.941 total time=   0.0s
# [CV 4/5] END n_neighbors=45, p=2, weights=distance;, score=0.906 total time=   0.0s
# [CV 5/5] END n_neighbors=45, p=2, weights=distance;, score=0.965 total time=   0.0s
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(10, 50, 5), 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              verbose=5)

# %%
estimator.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=10, p=1, weights='distance')

# %%
model = estimator.best_estimator_

# %%
report(y_train, model.predict(X_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       267
#            1       1.00      1.00      1.00       159
#
#     accuracy                           1.00       426
#    macro avg       1.00      1.00      1.00       426
# weighted avg       1.00      1.00      1.00       426
#
# ----------------------------------------------------------------------------------------------------
#      B    M
# B  267    0
# M    0  159

# %%
report(y_test, model.predict(X_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        90
#            1       0.92      0.92      0.92        53
#
#     accuracy                           0.94       143
#    macro avg       0.94      0.94      0.94       143
# weighted avg       0.94      0.94      0.94       143
#
# ----------------------------------------------------------------------------------------------------
#     B   M
# B  86   4
# M   4  49
