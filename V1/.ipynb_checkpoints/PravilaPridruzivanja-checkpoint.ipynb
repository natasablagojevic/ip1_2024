# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel('../datasets/izborni_predmeti.xlsx')

# %%
dataset
# Out:
#        INDEKS                  NAZIV_PREDMETA  \
# 0    20060173              Uvod u verovatnocu
# 1    20060249              Uvod u verovatnocu
# 2    20060024        Obrada rezultata merenja
# 3    20060029               Uvod u filosofiju
# 4    20060061               Uvod u filosofiju
# ..        ...                             ...
# 551  20072002                  Teorija modela
# 552  20072002                 Teorija skupova
# 553  20072020                 XML-tehnologije
# 554  20072020              Racunarska grafika
# 555  20072013  Odabrana poglavlja astronomije
#
#                                     NAZIV_SMERA
# 0             Profesor matematike i racunarstva
# 1             Profesor matematike i racunarstva
# 2                                   Astrofizika
# 3                                   Astrofizika
# 4                                   Astrofizika
# ..                                          ...
# 551  Matematicka logika i teorijsko racunarstvo
# 552  Matematicka logika i teorijsko racunarstvo
# 553                   Racunarstvo i informatika
# 554                   Racunarstvo i informatika
# 555                                 Astronomija
#
# [556 rows x 3 columns]

# %%
f = lambda x: x['NAZIV_SMERA'] in ['Informatika', 'Racunarstvo i informatika']

# %%
dataset = dataset[dataset.apply(f, axis=1)]

# %%
dataset = dataset.groupby(['INDEKS'])['NAZIV_PREDMETA'].apply(list).values.tolist()

# %%
dataset
# Out:
# [['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Teorija izracunljivosti', 'Programske paradigme'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Osnovi astronomije A', 'Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Osnovi astronomije A', 'Strani jezik 1', 'Programske paradigme'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Osnovi astronomije A', 'Strani jezik 1', 'Programske paradigme'],
#  ['Strani jezik 1',
#   'Taja A',
#   'Programske paradigme',
#   'Strani jezik 2',
#   'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Programske paradigme'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja B', 'Strani jezik 1', 'Taja A'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Strani jezik 2'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1'],
#  ['Strani jezik 1'],
#  ['Programske paradigme'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Teorija izracunljivosti', 'Programske paradigme'],
#  ['Teorija izracunljivosti', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Teorija izracunljivosti'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Strani jezik 1'],
#  ['Strani jezik 1', 'Strani jezik 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Teorija izracunljivosti', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Analiza i dizajn algoritama 2'],
#  ['Analiza i dizajn algoritama 2', 'Automatsko rezonovanje'],
#  ['Teorija izracunljivosti', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Programske paradigme', 'Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Analiza i dizajn algoritama 2'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Programske paradigme'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2'],
#  ['Automatsko rezonovanje'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Baze podataka-napredni koncepti',
#   'XML-tehnologije',
#   'Masinsko ucenje',
#   'Pretrazivanje informacija i istr. Veba',
#   'Teorija jezika i automata'],
#  ['Slozenost izracunavanja',
#   'XML-tehnologije',
#   'Baze podataka-napredni koncepti',
#   'Soft Computing',
#   'Geometrijski algoritmi',
#   'Simbolicko izracunavanje',
#   'Analiza i konstrukcija algoritama',
#   'Automatsko rezonovanje',
#   'XML-tehnologije',
#   'Pretrazivanje informacija i istr. Veba'],
#  ['Graficki korisnicki interfejsi',
#   'XML-tehnologije',
#   'Arhitektura slozenih softverskih sistema',
#   'Razvoj zasnovan na softverskim komponentama',
#   'Softversko inzenjerstvo'],
#  ['Baze podataka-napredni koncepti',
#   'Programske paradigme',
#   'Projektovanje baza podataka',
#   'Teorija baza podataka',
#   'Baze podataka-napredni koncepti',
#   'Programske paradigme',
#   'Projektovanje baza podataka',
#   'Teorija baza podataka'],
#  ['Teorija izracunljivosti',
#   'Soft Computing',
#   'Geometrijski algoritmi',
#   'Kriptografija',
#   'Naucno izracunavanje',
#   'Soft Computing',
#   'Geometrijski algoritmi',
#   'Kriptografija',
#   'Naucno izracunavanje',
#   'Teorija izracunljivosti'],
#  ['Baze podataka-napredni koncepti',
#   'Logicko programiranje',
#   'Projektovanje baza podataka',
#   'Softversko inzenjerstvo',
#   'Baze podataka-napredni koncepti',
#   'Logicko programiranje',
#   'Projektovanje baza podataka',
#   'Softversko inzenjerstvo'],
#  ['Baze podataka-napredni koncepti',
#   'Arhitektura slozenih softverskih sistema',
#   'Projektovanje softvera',
#   'Razvoj softvera',
#   'Softversko inzenjerstvo',
#   'Arhitektura slozenih softverskih sistema',
#   'Baze podataka-napredni koncepti',
#   'Projektovanje softvera',
#   'Razvoj softvera',
#   'Softversko inzenjerstvo'],
#  ['Baze podataka-napredni koncepti',
#   'Arhitektura slozenih softverskih sistema',
#   'Kriptografija',
#   'Projektovanje baza podataka'],
#  ['Automatsko rezonovanje',
#   'Soft Computing',
#   'Genetski algoritmi',
#   'Naucno izracunavanje',
#   'Slozenost izracunavanja',
#   'Soft Computing',
#   'Automatsko rezonovanje',
#   'Genetski algoritmi',
#   'Naucno izracunavanje',
#   'Kriptografija'],
#  ['Baze podataka-napredni koncepti',
#   'XML-tehnologije',
#   'Masinsko ucenje',
#   'Pretrazivanje informacija i istr. Veba',
#   'Teorija jezika i automata',
#   'Baze podataka-napredni koncepti',
#   'Masinsko ucenje',
#   'Teorija jezika i automata',
#   'Konstrukcija kompilatora',
#   'Obrada prirodnih jezika'],
#  ['Obrazci dizajna i prefabrikacija',
#   'Soft Computing',
#   'Vizuelizacija',
#   'Masinsko ucenje',
#   'Obrazci dizajna i prefabrikacija',
#   'Analiza i konstrukcija algoritama',
#   'Soft Computing',
#   'Vizuelizacija',
#   'Masinsko ucenje'],
#  ['Napredne arhitekture racunara',
#   'Vizuelizacija',
#   'Genetski algoritmi',
#   'Operativni sistemi',
#   'Programiranje za WWW',
#   'Vizuelizacija',
#   'Genetski algoritmi',
#   'Napredne arhitekture racunara',
#   'Operativni sistemi',
#   'Programiranje za WWW'],
#  ['Napredne arhitekture racunara',
#   'Genetski algoritmi',
#   'Operativni sistemi',
#   'Programiranje za WWW',
#   'Racunarske mreze',
#   'Genetski algoritmi',
#   'Napredne arhitekture racunara',
#   'Operativni sistemi',
#   'Programiranje za WWW',
#   'Racunarske mreze'],
#  ['Uvod u verovatnocu'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Taja B'],
#  ['Taja A', 'Osnovi astronomije A', 'Taja B'],
#  ['Taja A', 'Strani jezik 1', 'Taja B', 'Strani jezik 2'],
#  ['Taja A',
#   'Strani jezik 1',
#   'Programske paradigme',
#   'Taja B',
#   'Strani jezik 2'],
#  ['Taja A',
#   'Strani jezik 1',
#   'Osnovi astronomije A',
#   'Taja B',
#   'Strani jezik 2'],
#  ['Taja A', 'Strani jezik 1', 'Taja B', 'Strani jezik 2'],
#  ['Baze podataka-napredni koncepti',
#   'Konstrukcija kompilatora',
#   'XML-tehnologije',
#   'Masinsko ucenje',
#   'Obrada prirodnih jezika'],
#  ['Baze podataka-napredni koncepti',
#   'XML-tehnologije',
#   'Algoritmi teksta',
#   'Masinsko ucenje',
#   'Teorija jezika i automata'],
#  ['Analiza i konstrukcija algoritama',
#   'Napredne arhitekture racunara',
#   'Genetski algoritmi',
#   'Masinsko ucenje'],
#  ['Automatsko rezonovanje',
#   'Soft Computing',
#   'XML-tehnologije',
#   'Istrazivanje podataka',
#   'Masinsko ucenje'],
#  ['Programske paradigme',
#   'Soft Computing',
#   'XML-tehnologije',
#   'Genetski algoritmi',
#   'Matematicka logika u racunarstvu'],
#  ['Arhitektura slozenih softverskih sistema',
#   'Individualni i istrazivacki rad 1',
#   'Individualni i istrazivacki rad 2',
#   'Istrazivanje podataka'],
#  ['Analiza i konstrukcija algoritama',
#   'Programske paradigme',
#   'Genetski algoritmi',
#   'Geometrijski algoritmi',
#   'XML-tehnologije',
#   'Racunarska grafika'],
#  ['Automatsko rezonovanje',
#   'Geometrijski algoritmi',
#   'Racunarska grafika',
#   'Robotika']]

# %%
from apriori_python import apriori

# %%
freqItem, rules = apriori(dataset, minSup=0.02, minConf=0.8)

# %%
pd.DataFrame(rules, columns=['Antecedent', 'Consequent', 'Confidence'])
# Out:
#                                            Antecedent  \
# 0                     {Analiza i dizajn algoritama 2}
# 1                                            {Taja A}
# 2                                    {Strani jezik 2}
# 3                       {Projektovanje baza podataka}
# 4                         {Teorija jezika i automata}
# 5            {Pretrazivanje informacija i istr. Veba}
# 6                         {Teorija jezika i automata}
# 7            {Pretrazivanje informacija i istr. Veba}
# 8                                            {Taja B}
# 9                         {Teorija jezika i automata}
# 10                    {Napredne arhitekture racunara}
# 11                        {Teorija jezika i automata}
# 12  {Baze podataka-napredni koncepti, Teorija jezi...
# 13       {Teorija jezika i automata, Masinsko ucenje}
# 14                     {Taja B, Programske paradigme}
# 15                     {Programske paradigme, Taja A}
# 16  {Baze podataka-napredni koncepti, Masinsko uce...
# 17                           {Taja A, Strani jezik 2}
# 18                           {Taja B, Strani jezik 2}
# 19                           {Taja A, Strani jezik 2}
# 20             {Programske paradigme, Strani jezik 2}
# 21                           {Taja B, Strani jezik 2}
# 22                           {Taja B, Strani jezik 1}
# 23                           {Strani jezik 1, Taja A}
# 24                     {Taja B, Osnovi astronomije A}
# 25                     {Osnovi astronomije A, Taja A}
# 26           {Pretrazivanje informacija i istr. Veba}
# 27  {Baze podataka-napredni koncepti, Pretrazivanj...
# 28  {Pretrazivanje informacija i istr. Veba, XML-t...
# 29                        {Teorija jezika i automata}
# 30  {Baze podataka-napredni koncepti, Teorija jezi...
# 31       {XML-tehnologije, Teorija jezika i automata}
# 32                        {Teorija jezika i automata}
# 33       {Teorija jezika i automata, Masinsko ucenje}
# 34       {XML-tehnologije, Teorija jezika i automata}
# 35                        {Teorija jezika i automata}
# 36       {Teorija jezika i automata, Masinsko ucenje}
# 37  {Baze podataka-napredni koncepti, Teorija jezi...
# 38       {XML-tehnologije, Teorija jezika i automata}
# 39  {Baze podataka-napredni koncepti, Teorija jezi...
# 40  {XML-tehnologije, Teorija jezika i automata, M...
# 41  {Baze podataka-napredni koncepti, XML-tehnolog...
# 42                           {Taja B, Strani jezik 2}
# 43                           {Taja A, Strani jezik 2}
# 44           {Taja B, Strani jezik 1, Strani jezik 2}
# 45                   {Taja B, Taja A, Strani jezik 2}
# 46           {Strani jezik 1, Taja A, Strani jezik 2}
#
#                                            Consequent  Confidence
# 0                              {Programske paradigme}    0.833333
# 1                                            {Taja B}    0.977778
# 2                                    {Strani jezik 1}    1.000000
# 3                   {Baze podataka-napredni koncepti}    1.000000
# 4                   {Baze podataka-napredni koncepti}    1.000000
# 5                   {Baze podataka-napredni koncepti}    1.000000
# 6                                   {XML-tehnologije}    1.000000
# 7                                   {XML-tehnologije}    1.000000
# 8                                            {Taja A}    1.000000
# 9                                   {Masinsko ucenje}    1.000000
# 10                               {Genetski algoritmi}    1.000000
# 11  {Baze podataka-napredni koncepti, Masinsko uce...    1.000000
# 12                                  {Masinsko ucenje}    1.000000
# 13                  {Baze podataka-napredni koncepti}    1.000000
# 14                                           {Taja A}    1.000000
# 15                                           {Taja B}    1.000000
# 16                                  {XML-tehnologije}    1.000000
# 17                                   {Strani jezik 1}    1.000000
# 18                                           {Taja A}    1.000000
# 19                                           {Taja B}    1.000000
# 20                                   {Strani jezik 1}    1.000000
# 21                                   {Strani jezik 1}    1.000000
# 22                                           {Taja A}    1.000000
# 23                                           {Taja B}    1.000000
# 24                                           {Taja A}    1.000000
# 25                                           {Taja B}    1.000000
# 26  {Baze podataka-napredni koncepti, XML-tehnolog...    1.000000
# 27                                  {XML-tehnologije}    1.000000
# 28                  {Baze podataka-napredni koncepti}    1.000000
# 29  {Baze podataka-napredni koncepti, XML-tehnolog...    1.000000
# 30                                  {XML-tehnologije}    1.000000
# 31                  {Baze podataka-napredni koncepti}    1.000000
# 32                 {XML-tehnologije, Masinsko ucenje}    1.000000
# 33                                  {XML-tehnologije}    1.000000
# 34                                  {Masinsko ucenje}    1.000000
# 35  {Baze podataka-napredni koncepti, XML-tehnolog...    1.000000
# 36  {Baze podataka-napredni koncepti, XML-tehnolog...    1.000000
# 37                 {XML-tehnologije, Masinsko ucenje}    1.000000
# 38  {Baze podataka-napredni koncepti, Masinsko uce...    1.000000
# 39                                  {XML-tehnologije}    1.000000
# 40                  {Baze podataka-napredni koncepti}    1.000000
# 41                                  {Masinsko ucenje}    1.000000
# 42                           {Strani jezik 1, Taja A}    1.000000
# 43                           {Taja B, Strani jezik 1}    1.000000
# 44                                           {Taja A}    1.000000
# 45                                   {Strani jezik 1}    1.000000
# 46                                           {Taja B}    1.000000
