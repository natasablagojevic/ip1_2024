# %%
import seaborn as sns
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = sns.load_dataset('titanic') # dobijam pandas data frame
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['survived'] # dobijam pandas seriju 
df[['survived']] # dobijamo kolonu
# Out:
#      survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
df.head() # dobijam prvih 5 redova
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# daj mi deskriptivne statistike 
# mean, std deviation, min, max, percentiles(25% vrednosti u nizu manjih od tih)
# 50% percentil = medijana = Q2 
# 25% = Q1(kvartil) --- govori dosta
# 75% = Q3(kvartil) --- govori dosta 
# uzima samo numericke atribute 

df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# prikaz nedostajucih vrednosti
# False - ako nema nedostajucu vrednost
df.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
# prebrojavam koliko zapravo imam nedostajucih vrednosti; sabiramo po kolonama; za svaku kolonu imam po jedan broj
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# da bismo racunali prosek treba da imamo razmerni atribut
#
# najcesca vrednost koja se javlja u jednom nizu = moda
#
# - sta je najlakse da u radimo?
#   - da DECK kao kolonu izbacimo u potpunosti
#   -

# %%
df['deck'].unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df['age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# iskrivljenost = skewness = mera iskrivljenosti

# %%
df['age'].mean()
# Out:
# 29.69911764705882

# %%
# vraca novi pandas objekat 
# svi brojevi su celi, ali dodali smo nesto sto nije ceo broj
#

df['age'].fillna(df['age'].mean()).transform('mean')['age']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 5
#       1 # vraca novi pandas objekat
#       2 # svi brojevi su celi, ali dodali smo nesto sto nije ceo broj
#       3 #
# ----> 5 df['age'].fillna(df['age'].mean()).transform('mean')['age']
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4626, in Series.transform(self, func, axis, *args, **kwargs)
#    4624 self._get_axis_number(axis)
#    4625 ser = self.copy(deep=False) if using_copy_on_write() else self
# -> 4626 result = SeriesApply(ser, func=func, args=args, kwargs=kwargs).transform()
#    4627 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:252, in Apply.transform(self)
#     245 # error: Argument 1 to "__get__" of "AxisProperty" has incompatible type
#     246 # "Union[Series, DataFrame, GroupBy[Any], SeriesGroupBy,
# ...

# %%
# kada grupisemo po klasi hocemo da izracunamo broj godina
# moramo da gledamo da li postoji neka korelacija izmedju podataka sa kojima radimo 
# korelacija = koliko su neki podaci linearno zavisni

df[['pclass', 'age']].groupby('pclass').mean('age').transform('mean')['age']
# Out:
#               age
# pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %%
# sns.heatmap(df.corr())
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 # sns.heatmap(df.corr())
# ----> 2 df.corr()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
# prepisi ono sto je iznad
df['deck'].ffill()

# df['deck'].bfill() - kada su podaci sortirani po vremenu, popunjavamo sa vrednostima odozdo
# Out:
# 0      NaN
# 1        C
# 2        C
# 3        C
# 4        C
#       ...
# 886      C
# 887      B
# 888      B
# 889      C
# 890      C
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer

# %%
imputer = SimpleImputer()
imputer.fit_transform(df[['age']])
# Out:
# array([[22.        ],
#        [38.        ],
#        [26.        ],
#        [35.        ],
#        [35.        ],
#        [29.69911765],
#        [54.        ],
#        [ 2.        ],
#        [27.        ],
#        [14.        ],
#        [ 4.        ],
#        [58.        ],
#        [20.        ],
#        [39.        ],
#        [14.        ],
#        [55.        ],
#        [ 2.        ],
#        [29.69911765],
#        [31.        ],
#        [29.69911765],
#        [35.        ],
#        [34.        ],
#        [15.        ],
#        [28.        ],
#        [ 8.        ],
#        [38.        ],
#        [29.69911765],
#        [19.        ],
#        [29.69911765],
#        [29.69911765],
#        [40.        ],
#        [29.69911765],
#        [29.69911765],
#        [66.        ],
#        [28.        ],
#        [42.        ],
#        [29.69911765],
#        [21.        ],
#        [18.        ],
#        [14.        ],
#        [40.        ],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
# na osnovu ostalih vrednosti koju znamo, hocemo da predvidimo vrednost koju ne znamo
IterativeImputer(estimator=LinearRegression()).fit_transform(df[['age', 'fare']])

# zakljucio je da je najbolji broj bio 29
# Out:
# array([[22.        ,  7.25      ],
#        [38.        , 71.2833    ],
#        [26.        ,  7.925     ],
#        ...,
#        [29.40259123, 23.45      ],
#        [26.        , 30.        ],
#        [32.        ,  7.75      ]])

# %%
# trebalo bi i bilo bi pozeljno da imamo vise numerickih vrednosti
