# %%
import pandas as pd

# %%
df = pd.read_csv('./datasets/dogs.csv')

# %%
df
# Out:
#                    breed  height  weight
# 0          Border Collie      20      45
# 1         Boston Terrier      16      20
# 2       Brittany Spaniel      18      35
# 3            Bullmastiff      27     120
# 4              Chihuahua       8       8
# 5        German Shepherd      25      78
# 6       Golden Retriever      23      70
# 7             Great Dane      32     160
# 8   Portuguese Water Dog      21      50
# 9        Standard Poodle      19      65
# 10     Yorkshire Terrier       6       7

# %%
feature_names = df.columns[1:]

# %%
X = df[feature_names]
X
# Out:
#     height  weight
# 0       20      45
# 1       16      20
# 2       18      35
# 3       27     120
# 4        8       8
# 5       25      78
# 6       23      70
# 7       32     160
# 8       21      50
# 9       19      65
# 10       6       7

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(X)
# Out:
# MinMaxScaler()

# %%
X = scaler.transform(X)

# %%
X = pd.DataFrame(X, columns=feature_names)
X
# Out:
#       height    weight
# 0   0.538462  0.248366
# 1   0.384615  0.084967
# 2   0.461538  0.183007
# 3   0.807692  0.738562
# 4   0.076923  0.006536
# 5   0.730769  0.464052
# 6   0.653846  0.411765
# 7   1.000000  1.000000
# 8   0.576923  0.281046
# 9   0.500000  0.379085
# 10  0.000000  0.000000

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model = AgglomerativeClustering(n_clusters=3, linkage='single', compute_distances=True)

# %%
model.fit(X)
# Out:
# AgglomerativeClustering(compute_distances=True, linkage='single', n_clusters=3)

# %%
model.labels_
# Out:
# array([0, 0, 0, 0, 2, 0, 0, 1, 0, 0, 2])

# %%
df[model.labels_ == 2]
# Out:
#                 breed  height  weight
# 4           Chihuahua       8       8
# 10  Yorkshire Terrier       6       7

# %%
model.children_[:, 0].shape
# Out:
# (10,)

# %%
model.distances_
# Out:
# array([0.05047034, 0.07720025, 0.09301156, 0.10094068, 0.1246148 ,
#        0.1246148 , 0.15167269, 0.28508383, 0.31753116, 0.32454896])

# %%
import numpy as np

# %%
model.children_.shape
# Out:
# (10, 2)

# %%
model.distances_.reshape(-1,1).shape
# Out:
# (10, 1)

# %%
n_samples = len(model.labels_)
counts = np.zeros(model.children_.shape[0])

for i, (left, right) in enumerate(model.children_):
    count_left = 1 if left < n_samples else counts[left - n_samples]
    count_right = 1 if right < n_samples else counts[right - n_samples]
    counts[i] = count_left + count_right

counts = counts.reshape(-1, 1)
counts = counts.flatten()

# %%
z = np.vstack((model.children_[:,0], model.children_[:,1], model.distances_, counts))
z = np.transpose(z)
z
# Out:
# array([[ 0.        ,  8.        ,  0.05047034,  2.        ],
#        [ 4.        , 10.        ,  0.07720025,  2.        ],
#        [ 6.        ,  5.        ,  0.09301156,  2.        ],
#        [11.        ,  2.        ,  0.10094068,  3.        ],
#        [14.        ,  9.        ,  0.1246148 ,  4.        ],
#        [15.        ,  1.        ,  0.1246148 ,  5.        ],
#        [16.        , 13.        ,  0.15167269,  7.        ],
#        [17.        ,  3.        ,  0.28508383,  8.        ],
#        [18.        , 12.        ,  0.31753116, 10.        ],
#        [19.        ,  7.        ,  0.32454896, 11.        ]])

# %%
 p = z[:, :-1]

# %%
p
# Out:
# array([[ 0.        ,  8.        ,  0.05047034],
#        [ 4.        , 10.        ,  0.07720025],
#        [ 6.        ,  5.        ,  0.09301156],
#        [11.        ,  2.        ,  0.10094068],
#        [14.        ,  9.        ,  0.1246148 ],
#        [15.        ,  1.        ,  0.1246148 ],
#        [16.        , 13.        ,  0.15167269],
#        [17.        ,  3.        ,  0.28508383],
#        [18.        , 12.        ,  0.31753116],
#        [19.        ,  7.        ,  0.32454896]])

# %%
z = p
z
# Out:
# array([[ 0.        ,  8.        ,  0.05047034],
#        [ 4.        , 10.        ,  0.07720025],
#        [ 6.        ,  5.        ,  0.09301156],
#        [11.        ,  2.        ,  0.10094068],
#        [14.        ,  9.        ,  0.1246148 ],
#        [15.        ,  1.        ,  0.1246148 ],
#        [16.        , 13.        ,  0.15167269],
#        [17.        ,  3.        ,  0.28508383],
#        [18.        , 12.        ,  0.31753116],
#        [19.        ,  7.        ,  0.32454896]])

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import silhouette_score

# %%
k = 3 
linkages = ['single', 'complete', 'average']
fig = plt.figure(figsize=(15,5))
for idx, linkage in enumerate(linkages):
    model = AgglomerativeClustering(n_clusters=k, linkage=linkage)
    model.fit(X)

    fig.add_subplot(1, len(linkages), idx+1)

    for cluster_label in range(k):
        cluster = df[model.labels_ == cluster_label]
        plt.scatter(cluster['height'], cluster['weight'])
    plt.title(f'l={linkage}, sil={silhouette_score(X, model.labels_)}')

plt.tight_layout()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
Z = linkage(X, method='average')
Z
# Out:
# array([[ 0.        ,  8.        ,  0.05047034,  2.        ],
#        [ 4.        , 10.        ,  0.07720025,  2.        ],
#        [ 5.        ,  6.        ,  0.09301156,  2.        ],
#        [ 1.        ,  2.        ,  0.1246148 ,  2.        ],
#        [ 9.        , 11.        ,  0.1304373 ,  3.        ],
#        [14.        , 15.        ,  0.21119649,  5.        ],
#        [13.        , 16.        ,  0.29077603,  7.        ],
#        [ 3.        ,  7.        ,  0.32454896,  2.        ],
#        [12.        , 17.        ,  0.59213162,  9.        ],
#        [18.        , 19.        ,  0.80001992, 11.        ]])

# %%
dendrogram(Z, labels=df.index)
# Out:
# {'icoord': [[5.0, 5.0, 15.0, 15.0],
#   [25.0, 25.0, 35.0, 35.0],
#   [45.0, 45.0, 55.0, 55.0],
#   [65.0, 65.0, 75.0, 75.0],
#   [95.0, 95.0, 105.0, 105.0],
#   [85.0, 85.0, 100.0, 100.0],
#   [70.0, 70.0, 92.5, 92.5],
#   [50.0, 50.0, 81.25, 81.25],
#   [30.0, 30.0, 65.625, 65.625],
#   [10.0, 10.0, 47.8125, 47.8125]],
#  'dcoord': [[0.0, 0.3245489616681213, 0.3245489616681213, 0.0],
#   [0.0, 0.07720024854761205, 0.07720024854761205, 0.0],
#   [0.0, 0.0930115635997988, 0.0930115635997988, 0.0],
#   [0.0, 0.12461479677668082, 0.12461479677668082, 0.0],
#   [0.0, 0.05047034033286324, 0.05047034033286324, 0.0],
#   [0.0, 0.13043730177263782, 0.13043730177263782, 0.05047034033286324],
#   [0.12461479677668082,
#    0.21119648520243292,
#    0.21119648520243292,
#    0.13043730177263782],
#   [0.0930115635997988,
#    0.29077602711943384,
#    0.29077602711943384,
#    0.21119648520243292],
#   [0.07720024854761205,
#    0.5921316164491732,
#    0.5921316164491732,
#    0.29077602711943384],
#   [0.3245489616681213,
#    0.800019923660881,
#    0.800019923660881,
#    0.5921316164491732]],
#  'ivl': [3, 7, 4, 10, 5, 6, 1, 2, 9, 0, 8],
#  'leaves': [3, 7, 4, 10, 5, 6, 1, 2, 9, 0, 8],
#  'color_list': ['C1', 'C2', 'C3', 'C3', 'C3', 'C3', 'C3', 'C3', 'C0', 'C0'],
#  'leaves_color_list': ['C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3']}

# %%
df.index
# Out:
# RangeIndex(start=0, stop=11, step=1)

# %%
X = X.set_index(df['breed'])

# %%
_ = dendrogram(Z, labels=X.index, leaf_rotation=90)

# %%
from sklearn.cluster import DBSCAN

# %%
model = DBSCAN(eps=0.1, min_samples=2)

# %%
model.fit(X)
# Out:
# DBSCAN(eps=0.1, min_samples=2)

# %%
model.labels_
# Out:
# array([ 0, -1, -1, -1,  1,  2,  2, -1,  0, -1,  1])

# %%
np.unique(model.labels_)
# Out:
# array([-1,  0,  1,  2])

# %%
min_samples = 2
eps_values = [0.1, 0.15, 0.2, 0.25, 0.3]
min_samples_values = range(2, 5)
fig = plt.figure(figsize=(25,10))
idx = 1
for eps in eps_values:
    for min_samples in min_samples_values:
        model = DBSCAN(eps=eps, min_samples=min_samples)
        model.fit(X)

        fig.add_subplot(len(eps_values), len(min_samples_values), idx)
        idx += 1 
        
        for cluster_label in np.unique(model.labels_):
            cluster = df[model.labels_ == cluster_label]
            if cluster_label == -1:
                plt.scatter(cluster['height'], cluster['weight'], color='black', label='sum')
            else:
                plt.scatter(cluster['height'], cluster['weight'], label=f'klaster {cluster_label}')
        
        plt.legend()
        if len(np.unique(model.labels_)) == 1:
            s = None 
        else:
            s = silhouette_score(X, model.labels_)
        plt.title(f'eps={eps}, m={min_samples}, sil={s}')

plt.tight_layout()
