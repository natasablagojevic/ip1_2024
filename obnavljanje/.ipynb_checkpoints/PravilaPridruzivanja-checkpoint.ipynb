# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install apriori_python
# Out:
# Requirement already satisfied: apriori_python in /home/natasa/anaconda3/lib/python3.11/site-packages (1.0.4)

# %%
dataset = pd.read_excel('./datasets/izborni_predmeti.xlsx')

# %%
dataset
# Out:
#        INDEKS                  NAZIV_PREDMETA  \
# 0    20060173              Uvod u verovatnocu
# 1    20060249              Uvod u verovatnocu
# 2    20060024        Obrada rezultata merenja
# 3    20060029               Uvod u filosofiju
# 4    20060061               Uvod u filosofiju
# ..        ...                             ...
# 551  20072002                  Teorija modela
# 552  20072002                 Teorija skupova
# 553  20072020                 XML-tehnologije
# 554  20072020              Racunarska grafika
# 555  20072013  Odabrana poglavlja astronomije
#
#                                     NAZIV_SMERA
# 0             Profesor matematike i racunarstva
# 1             Profesor matematike i racunarstva
# 2                                   Astrofizika
# 3                                   Astrofizika
# 4                                   Astrofizika
# ..                                          ...
# 551  Matematicka logika i teorijsko racunarstvo
# 552  Matematicka logika i teorijsko racunarstvo
# 553                   Racunarstvo i informatika
# 554                   Racunarstvo i informatika
# 555                                 Astronomija
#
# [556 rows x 3 columns]

# %%
f = lambda x: x['NAZIV_SMERA'] in ['Informatika', 'Racunarstvo i informatika']
dataset = dataset[dataset.apply(f, axis=1)]

# %%
dataset = dataset.groupby(['INDEKS'])['NAZIV_PREDMETA'].apply(list).values.tolist()

# %%
dataset
# Out:
# [['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Teorija izracunljivosti', 'Programske paradigme'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Osnovi astronomije A', 'Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Osnovi astronomije A', 'Strani jezik 1', 'Programske paradigme'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Osnovi astronomije A', 'Strani jezik 1', 'Programske paradigme'],
#  ['Strani jezik 1',
#   'Taja A',
#   'Programske paradigme',
#   'Strani jezik 2',
#   'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Programske paradigme'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja B', 'Strani jezik 1', 'Taja A'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Strani jezik 2'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1', 'Taja A', 'Taja B'],
#  ['Strani jezik 1'],
#  ['Strani jezik 1'],
#  ['Programske paradigme'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Teorija izracunljivosti', 'Programske paradigme'],
#  ['Teorija izracunljivosti', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Teorija izracunljivosti'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Strani jezik 1'],
#  ['Strani jezik 1', 'Strani jezik 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Teorija izracunljivosti', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Analiza i dizajn algoritama 2'],
#  ['Analiza i dizajn algoritama 2', 'Automatsko rezonovanje'],
#  ['Teorija izracunljivosti', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Programske paradigme', 'Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Analiza i dizajn algoritama 2'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Programske paradigme'],
#  ['Teorija izracunljivosti', 'Automatsko rezonovanje'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2'],
#  ['Automatsko rezonovanje'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Strani jezik 1'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Analiza i dizajn algoritama 2', 'Programske paradigme'],
#  ['Baze podataka-napredni koncepti',
#   'XML-tehnologije',
#   'Masinsko ucenje',
#   'Pretrazivanje informacija i istr. Veba',
#   'Teorija jezika i automata'],
#  ['Slozenost izracunavanja',
#   'XML-tehnologije',
#   'Baze podataka-napredni koncepti',
#   'Soft Computing',
#   'Geometrijski algoritmi',
#   'Simbolicko izracunavanje',
#   'Analiza i konstrukcija algoritama',
#   'Automatsko rezonovanje',
#   'XML-tehnologije',
#   'Pretrazivanje informacija i istr. Veba'],
#  ['Graficki korisnicki interfejsi',
#   'XML-tehnologije',
#   'Arhitektura slozenih softverskih sistema',
#   'Razvoj zasnovan na softverskim komponentama',
#   'Softversko inzenjerstvo'],
#  ['Baze podataka-napredni koncepti',
#   'Programske paradigme',
#   'Projektovanje baza podataka',
#   'Teorija baza podataka',
#   'Baze podataka-napredni koncepti',
#   'Programske paradigme',
#   'Projektovanje baza podataka',
#   'Teorija baza podataka'],
#  ['Teorija izracunljivosti',
#   'Soft Computing',
#   'Geometrijski algoritmi',
#   'Kriptografija',
#   'Naucno izracunavanje',
#   'Soft Computing',
#   'Geometrijski algoritmi',
#   'Kriptografija',
#   'Naucno izracunavanje',
#   'Teorija izracunljivosti'],
#  ['Baze podataka-napredni koncepti',
#   'Logicko programiranje',
#   'Projektovanje baza podataka',
#   'Softversko inzenjerstvo',
#   'Baze podataka-napredni koncepti',
#   'Logicko programiranje',
#   'Projektovanje baza podataka',
#   'Softversko inzenjerstvo'],
#  ['Baze podataka-napredni koncepti',
#   'Arhitektura slozenih softverskih sistema',
#   'Projektovanje softvera',
#   'Razvoj softvera',
#   'Softversko inzenjerstvo',
#   'Arhitektura slozenih softverskih sistema',
#   'Baze podataka-napredni koncepti',
#   'Projektovanje softvera',
#   'Razvoj softvera',
#   'Softversko inzenjerstvo'],
#  ['Baze podataka-napredni koncepti',
#   'Arhitektura slozenih softverskih sistema',
#   'Kriptografija',
#   'Projektovanje baza podataka'],
#  ['Automatsko rezonovanje',
#   'Soft Computing',
#   'Genetski algoritmi',
#   'Naucno izracunavanje',
#   'Slozenost izracunavanja',
#   'Soft Computing',
#   'Automatsko rezonovanje',
#   'Genetski algoritmi',
#   'Naucno izracunavanje',
#   'Kriptografija'],
#  ['Baze podataka-napredni koncepti',
#   'XML-tehnologije',
#   'Masinsko ucenje',
#   'Pretrazivanje informacija i istr. Veba',
#   'Teorija jezika i automata',
#   'Baze podataka-napredni koncepti',
#   'Masinsko ucenje',
#   'Teorija jezika i automata',
#   'Konstrukcija kompilatora',
#   'Obrada prirodnih jezika'],
#  ['Obrazci dizajna i prefabrikacija',
#   'Soft Computing',
#   'Vizuelizacija',
#   'Masinsko ucenje',
#   'Obrazci dizajna i prefabrikacija',
#   'Analiza i konstrukcija algoritama',
#   'Soft Computing',
#   'Vizuelizacija',
#   'Masinsko ucenje'],
#  ['Napredne arhitekture racunara',
#   'Vizuelizacija',
#   'Genetski algoritmi',
#   'Operativni sistemi',
#   'Programiranje za WWW',
#   'Vizuelizacija',
#   'Genetski algoritmi',
#   'Napredne arhitekture racunara',
#   'Operativni sistemi',
#   'Programiranje za WWW'],
#  ['Napredne arhitekture racunara',
#   'Genetski algoritmi',
#   'Operativni sistemi',
#   'Programiranje za WWW',
#   'Racunarske mreze',
#   'Genetski algoritmi',
#   'Napredne arhitekture racunara',
#   'Operativni sistemi',
#   'Programiranje za WWW',
#   'Racunarske mreze'],
#  ['Uvod u verovatnocu'],
#  ['Taja A', 'Programske paradigme', 'Taja B'],
#  ['Taja A', 'Taja B'],
#  ['Taja A', 'Osnovi astronomije A', 'Taja B'],
#  ['Taja A', 'Strani jezik 1', 'Taja B', 'Strani jezik 2'],
#  ['Taja A',
#   'Strani jezik 1',
#   'Programske paradigme',
#   'Taja B',
#   'Strani jezik 2'],
#  ['Taja A',
#   'Strani jezik 1',
#   'Osnovi astronomije A',
#   'Taja B',
#   'Strani jezik 2'],
#  ['Taja A', 'Strani jezik 1', 'Taja B', 'Strani jezik 2'],
#  ['Baze podataka-napredni koncepti',
#   'Konstrukcija kompilatora',
#   'XML-tehnologije',
#   'Masinsko ucenje',
#   'Obrada prirodnih jezika'],
#  ['Baze podataka-napredni koncepti',
#   'XML-tehnologije',
#   'Algoritmi teksta',
#   'Masinsko ucenje',
#   'Teorija jezika i automata'],
#  ['Analiza i konstrukcija algoritama',
#   'Napredne arhitekture racunara',
#   'Genetski algoritmi',
#   'Masinsko ucenje'],
#  ['Automatsko rezonovanje',
#   'Soft Computing',
#   'XML-tehnologije',
#   'Istrazivanje podataka',
#   'Masinsko ucenje'],
#  ['Programske paradigme',
#   'Soft Computing',
#   'XML-tehnologije',
#   'Genetski algoritmi',
#   'Matematicka logika u racunarstvu'],
#  ['Arhitektura slozenih softverskih sistema',
#   'Individualni i istrazivacki rad 1',
#   'Individualni i istrazivacki rad 2',
#   'Istrazivanje podataka'],
#  ['Analiza i konstrukcija algoritama',
#   'Programske paradigme',
#   'Genetski algoritmi',
#   'Geometrijski algoritmi',
#   'XML-tehnologije',
#   'Racunarska grafika'],
#  ['Automatsko rezonovanje',
#   'Geometrijski algoritmi',
#   'Racunarska grafika',
#   'Robotika']]

# %%
from apriori_python import apriori

# %%
freqItem, rules = apriori(dataset, minSup=0.02, minConf=0.80)

# %%
pd.DataFrame(rules, columns=['Antecedent', 'Consequent', 'Confidence'])
# Out:
#                                            Antecedent  \
# 0                     {Analiza i dizajn algoritama 2}
# 1                                            {Taja A}
# 2                                    {Strani jezik 2}
# 3            {Pretrazivanje informacija i istr. Veba}
# 4                         {Teorija jezika i automata}
# 5                       {Projektovanje baza podataka}
# 6                         {Teorija jezika i automata}
# 7                                            {Taja B}
# 8            {Pretrazivanje informacija i istr. Veba}
# 9                     {Napredne arhitekture racunara}
# 10                        {Teorija jezika i automata}
# 11                        {Teorija jezika i automata}
# 12       {Masinsko ucenje, Teorija jezika i automata}
# 13       {Teorija jezika i automata, XML-tehnologije}
# 14                           {Taja A, Strani jezik 2}
# 15                           {Strani jezik 2, Taja A}
# 16                           {Strani jezik 2, Taja B}
# 17                           {Strani jezik 1, Taja A}
# 18                           {Strani jezik 1, Taja B}
# 19                        {Teorija jezika i automata}
# 20  {Baze podataka-napredni koncepti, Teorija jezi...
# 21       {Teorija jezika i automata, XML-tehnologije}
# 22                           {Strani jezik 2, Taja B}
# 23                        {Teorija jezika i automata}
# 24  {Baze podataka-napredni koncepti, Teorija jezi...
# 25       {Masinsko ucenje, Teorija jezika i automata}
# 26  {Baze podataka-napredni koncepti, Masinsko uce...
# 27           {Pretrazivanje informacija i istr. Veba}
# 28  {Baze podataka-napredni koncepti, Pretrazivanj...
# 29  {Pretrazivanje informacija i istr. Veba, XML-t...
# 30                     {Osnovi astronomije A, Taja A}
# 31                     {Osnovi astronomije A, Taja B}
# 32             {Strani jezik 2, Programske paradigme}
# 33                     {Taja A, Programske paradigme}
# 34                     {Programske paradigme, Taja B}
# 35                           {Strani jezik 2, Taja A}
# 36                           {Strani jezik 2, Taja B}
# 37           {Strani jezik 2, Strani jezik 1, Taja A}
# 38           {Strani jezik 1, Strani jezik 2, Taja B}
# 39                   {Strani jezik 2, Taja A, Taja B}
# 40                        {Teorija jezika i automata}
# 41  {Baze podataka-napredni koncepti, Teorija jezi...
# 42       {Masinsko ucenje, Teorija jezika i automata}
# 43       {Teorija jezika i automata, XML-tehnologije}
# 44  {Baze podataka-napredni koncepti, Masinsko uce...
# 45  {Baze podataka-napredni koncepti, Teorija jezi...
# 46  {Masinsko ucenje, Teorija jezika i automata, X...
#
#                                            Consequent  Confidence
# 0                              {Programske paradigme}    0.833333
# 1                                            {Taja B}    0.977778
# 2                                    {Strani jezik 1}    1.000000
# 3                                   {XML-tehnologije}    1.000000
# 4                                   {XML-tehnologije}    1.000000
# 5                   {Baze podataka-napredni koncepti}    1.000000
# 6                                   {Masinsko ucenje}    1.000000
# 7                                            {Taja A}    1.000000
# 8                   {Baze podataka-napredni koncepti}    1.000000
# 9                                {Genetski algoritmi}    1.000000
# 10                  {Baze podataka-napredni koncepti}    1.000000
# 11                 {Masinsko ucenje, XML-tehnologije}    1.000000
# 12                                  {XML-tehnologije}    1.000000
# 13                                  {Masinsko ucenje}    1.000000
# 14                                   {Strani jezik 1}    1.000000
# 15                                           {Taja B}    1.000000
# 16                                           {Taja A}    1.000000
# 17                                           {Taja B}    1.000000
# 18                                           {Taja A}    1.000000
# 19  {Baze podataka-napredni koncepti, XML-tehnolog...    1.000000
# 20                                  {XML-tehnologije}    1.000000
# 21                  {Baze podataka-napredni koncepti}    1.000000
# 22                                   {Strani jezik 1}    1.000000
# 23  {Baze podataka-napredni koncepti, Masinsko uce...    1.000000
# 24                                  {Masinsko ucenje}    1.000000
# 25                  {Baze podataka-napredni koncepti}    1.000000
# 26                                  {XML-tehnologije}    1.000000
# 27  {Baze podataka-napredni koncepti, XML-tehnolog...    1.000000
# 28                                  {XML-tehnologije}    1.000000
# 29                  {Baze podataka-napredni koncepti}    1.000000
# 30                                           {Taja B}    1.000000
# 31                                           {Taja A}    1.000000
# 32                                   {Strani jezik 1}    1.000000
# 33                                           {Taja B}    1.000000
# 34                                           {Taja A}    1.000000
# 35                           {Strani jezik 1, Taja B}    1.000000
# 36                           {Strani jezik 1, Taja A}    1.000000
# 37                                           {Taja B}    1.000000
# 38                                           {Taja A}    1.000000
# 39                                   {Strani jezik 1}    1.000000
# 40  {Baze podataka-napredni koncepti, Masinsko uce...    1.000000
# 41                 {Masinsko ucenje, XML-tehnologije}    1.000000
# 42  {Baze podataka-napredni koncepti, XML-tehnolog...    1.000000
# 43  {Baze podataka-napredni koncepti, Masinsko uce...    1.000000
# 44                                  {XML-tehnologije}    1.000000
# 45                                  {Masinsko ucenje}    1.000000
# 46                  {Baze podataka-napredni koncepti}    1.000000
